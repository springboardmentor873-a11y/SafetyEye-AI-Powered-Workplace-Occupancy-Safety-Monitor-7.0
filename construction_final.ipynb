# %%
# !kaggle datasets download -d snehilsanyal/construction-site-safety-image-dataset-roboflow
# Out:
# Dataset URL: https://www.kaggle.com/datasets/snehilsanyal/construction-site-safety-image-dataset-roboflow
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100% 206M/206M [00:00<00:00, 350MB/s]

# %%
import zipfile

with zipfile.ZipFile("/content/construction-site-safety-image-dataset-roboflow.zip", "r") as zip_ref:
    zip_ref.extractall("/content/dataset")

print("dataset extracted successfully!")
# Out:
# dataset extracted successfully!

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
print("yolov8 loaded successfully!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# yolov8 loaded successfully!

# %%
# !find /content/dataset -name "data.yaml"

# %%
# !ls /content
# Out:
# construction					     dataset	  sample_data
# construction-site-safety-image-dataset-roboflow.zip  kaggle.json  yolov8n.pt

# %%
# !ls /content/dataset
# Out:
# css-data  results_yolov8n_100e	source_files

# %%
# !find /content/dataset -iname "*yaml"
# Out:
# /content/dataset/results_yolov8n_100e/kaggle/working/runs/detect/train/args.yaml
# /content/dataset/results_yolov8n_100e/kaggle/working/ppe_data.yaml

# %%
# !cat /content/dataset/results_yolov8n_100e/kaggle/working/ppe_data.yaml
# Out:
# {names: [Hardhat, Mask, NO-Hardhat, NO-Mask, NO-Safety Vest, Person, Safety Cone,
#     Safety Vest, machinery, vehicle], nc: 10, test: /kaggle/input/construction-site-safety-image-dataset-roboflow/test,
#   train: /kaggle/input/construction-site-safety-image-dataset-roboflow/train, val: /kaggle/input/construction-site-safety-image-dataset-roboflow/valid}

# %%
# !ls /content/dataset/css-data
# Out:
# README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# %%writefile /content/dataset/css-data/data.yaml
#
#
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 10
#
# names:
#   0: hardhat
#   1: mask
#   2: no-hardhat
#   3: no-mask
#   4: no-safety-vest
#   5: person
#   6: safety-cone
#   7: safety-vest
#   8: machinery
#   9: vehicle
# Out:
# Writing /content/dataset/css-data/data.yaml

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/dataset/css-data/data.yaml",
    epochs=25,
    imgsz=640
)
# Out:
# Ultralytics 8.4.62 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content
# Out:
# construction					     kaggle.json  yolo26n.pt
# construction-site-safety-image-dataset-roboflow.zip  runs	  yolov8n.pt
# dataset						     sample_data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b814f19a-0738-4aa6-a262-7dd442c28d3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b814f19a-0738-4aa6-a262-7dd442c28d3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

results = model.predict(
    source="kkk.jpg",
    save=True
)
# Out:
# image 1/1 /content/kkk.jpg: 640x640 2 hardhats, 2 no-masks, 3 persons, 1 machinery, 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict-2

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("/content/runs/detect/predict-2/kkk.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
# !cp runs/detect/train/weights/best.pt /content/best.pt

# %%
from google.colab import files
files.download("/content/best.pt")

# %%
from google.colab import files
files.download("/content/runs/detect/predict-2/kkk.jpg")

# %%
# !zip -r project.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 18%)
#   adding: content/runs/detect/train/labels.jpg (deflated 20%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train/train_batch2447.jpg (deflated 5%)
#   adding: content/runs/detect/train/BoxR_curve.png (deflated 6%)
#   adding: content/runs/detect/train/args.yaml (deflated 53%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 5%)
#   adding: content/runs/detect/train/BoxP_curve.png (deflated 7%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train/train_batch2445.jpg (deflated 6%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 3%)
# ...
